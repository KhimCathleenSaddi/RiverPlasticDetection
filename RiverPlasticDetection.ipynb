# %% [markdown]
# # SETUP

# %%
### 2. Define root directory ###

ROOT_DIR = 'C:/Users/dottorandi/Desktop/KHM/sssss/yolov8'
print(ROOT_DIR)

# %%
# %pwd

# %%
# %cd yolov8

# %% [markdown]
# # Model Training

# %%
### 3. Install Ultralytics ###

# !pip install ultralytics

# %%
###### 4. Train model ###

import os

from ultralytics import YOLO

# Load a model
model = YOLO("yolov8n.pt")  # load pre trained model

# Load a model
model = YOLO(insert model path)

# Use the model
results = model.train(data=os.path.join(ROOT_DIR, "data.yaml"), epochs=300)  # train the model

# %% [markdown]
# # Inference

# %%
import os

from ultralytics import YOLO

# %%
# Run inference on an image with YOLOv8 - normal
# !yolo predict model='insert model path' source='insert image or video path'

# %%
# show the detected image

from PIL import Image
from IPython.display import display

img = Image.open('insert image or video path')

display(img)

# %%
# Run inference on an image with YOLOv8 for annotation generation
from ultralytics import YOLO

# Load the YOLOv8 model
model=YOLO('insert mode path')

# Define path to video file
source = "insert image or video path"

# Perform inference on an image
results = model(source, stream=True, save=True)

# View results
for r in results:
    print(r.boxes.xyxyn)  # print the Boxes object containing the detection bounding boxes

# %% [markdown]
# # GPU Check

# %%
# !pip install tensorflow

# %%
import tensorflow as tf

gpus = tf.config.list_physical_devices("GPU")

if gpus:
    for gpu in gpus:
        print("Found a GPU with the ID:", gpu)
else:
    print("Failed to detect a GPU")

# %%
# Checking for TORCH
import torch
print("Torch version:",torch.__version__)
print("Is CUDA enabled?",torch.cuda.is_available())

# %%
# Checking for GPU
if use_cuda:
    print('__CUDNN VERSION:', torch.backends.cudnn.version())
    print('__Number CUDA Devices:', torch.cuda.device_count())
    print('__CUDA Device Name:',torch.cuda.get_device_name(0))
    print('__CUDA Device Total Memory [GB]:',torch.cuda.get_device_properties(0).total_memory/1e9)

# %%
device = torch.device("cuda" if use_cuda else "cpu")
print("Device: ",device)

# %% [markdown]
# # Analysis

# %% [markdown]
# ##Manual Plot of Model Results

# %%
# Imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Load data
df = pd.read_csv('heart.csv')
df.head()

# %%
# !pip install scikit-learn

# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import precision_recall_curve
import matplotlib.pyplot as plt

# %%
#create dataset with 5 predictor variables
X, y = datasets.make_classification(n_samples=500,
                                    n_features=500,
                                    n_informative=10,
                                    n_redundant=0,
                                    random_state=0)

#split dataset into training and testing set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.3,random_state=0)

#fit logistic regression model to dataset
classifier = LogisticRegression()
classifier.fit(X_train, y_train)

#use logistic regression model to make predictions
y_score = classifier.predict_proba(X_test)[:, 1]

# %%
#calculate precision and recall
precision, recall, thresholds = precision_recall_curve(y_test, y_score)

#create precision recall curve
fig, ax = plt.subplots()
ax.plot(recall, precision, color='purple')

#add axis labels to plot
ax.set_title('Precision-Recall Curve')
ax.set_ylabel('Precision')
ax.set_xlabel('Recall')

#display plot
plt.show()

# %% [markdown]
# ##Analysis - Linear Regression (sample)

# %% [markdown]
# # Validation

# %%
# %pwd

# %%
# !pip install ultralytics

# %%
# %pwd

# %%
from ultralytics import YOLO

# Load a model
model = YOLO(r'insert model path')

# Customize validation settings
validation_results = model.val(data=r'insert data.yaml path', imgsz=640, batch=16, conf=0.25, iou=0.6, device="0")
